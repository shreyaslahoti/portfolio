# %%
# DataStructure
tails = ['T1','T2','T3','T4','T5','T6']

airports = ['AUS','DAL','HOU']

flight_time = { 'AUSHOU':45, 'HOUAUS':45, 'AUSDAL':50, 'DALAUS':50, 'DALHOU':65, 'HOUDAL':65 }

source_gate = ['AUS1','DAL1','DAL2', 'HOU1', 'HOU2', 'HOU3' ]

destination_gate = ['HOU1','HOU2', 'HOU3', 'AUS1', 'DAL1', 'DAL2']

ground_time = {'AUS':25, 'DAL':30, 'HOU':35 }
finalList = [['Tails', 'origin' , 'destination' , 'departure_time', 'arrival_time']]

# militaryTimeToMins
def militaryTimeToMins(mil):
    a=int(mil/100)
    a=a*60
    b=mil%100
    mins=a+b
    return(mins)


# minsToMiliteryTime
def mins2militery(mins):
    x = mins/60
    y= mins%60
    val1 = int(x)
    val2 = int(y) 
    if x<10:
        val1 = "%02d" % int(x)
    if y<10:
        val2 = "%02d" % int(y)
    val3 = str(val1) + str(val2)
    return val3    
        
#source_array
for flights in range(0,6):
    count=0
    for number in range(0,10):
        if source_gate[flights] == 'AUS1' and destination_gate[flights] == 'HOU1':
            first_flight= 360
            departure_time= first_flight + count
            count=count + 150
            arrival_time= departure_time + flight_time['AUSHOU']
            tempValSou = source_gate[flights][:3]
            tempValDest = destination_gate[flights][:3]
            if departure_time >359 and arrival_time < 1321:
                
                print(tails[flights],',', tempValSou,',', tempValDest,',', mins2militery(departure_time),',', mins2militery(arrival_time), sep="")
                tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                finalList.append(tempList)

                if source_gate[flights] == 'AUS1' and destination_gate[flights] == 'HOU1':
                    departure_time= arrival_time + ground_time['HOU']
                    arrival_time = departure_time + flight_time['HOUAUS']
                    if departure_time >359 and arrival_time < 1321:
                        tempValDest = destination_gate[flights][:3]
                        tempValSou = source_gate[flights][:3]
                        print(tails[flights],',',tempValDest,',', tempValSou,',', mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                        tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                        finalList.append(tempList)
    
    for number in range(0,10):
        if source_gate[flights] == 'DAL1' and destination_gate[flights] == 'HOU2':
            first_flight= 360
            departure_time= first_flight + count
            count=count + 195
            arrival_time= departure_time + flight_time['DALHOU']
            tempValDest = destination_gate[flights][:3]
            tempValSou = source_gate[flights][:3]
            if departure_time >359 and arrival_time < 1321:
                print(tails[flights],',', tempValSou,',', tempValDest,',',mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                finalList.append(tempList)
                    
                if source_gate[flights] == 'DAL1' and destination_gate[flights] == 'HOU2':
                    departure_time= arrival_time + ground_time['HOU']
                    arrival_time = departure_time + flight_time['HOUDAL']
                    tempValDest = destination_gate[flights][:3]
                    tempValSou = source_gate[flights][:3]
                    if departure_time >359 and arrival_time < 1321:
                        print(tails[flights],',', tempValDest,',', tempValSou,',', mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                        tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                        finalList.append(tempList)
    
    for number in range(0,10):
        if source_gate[flights] == 'DAL2' and destination_gate[flights] == 'HOU3':
            first_flight= 360
            departure_time= first_flight + count
            count=count + 195
            arrival_time= departure_time + flight_time['DALHOU']
            tempValDest = destination_gate[flights][:3]
            tempValSou = source_gate[flights][:3]
            if departure_time >359 and arrival_time < 1321:
                print(tails[flights],',', tempValSou,',', tempValDest,',',mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                finalList.append(tempList)    
                
                if source_gate[flights] == 'DAL2' and destination_gate[flights] == 'HOU3':
                    departure_time= arrival_time + ground_time['HOU']
                    arrival_time = departure_time + flight_time['HOUDAL']
                    tempValDest = destination_gate[flights][:3]
                    tempValSou = source_gate[flights][:3]
                    if departure_time >359 and arrival_time < 1321:
                        print(tails[flights],',', tempValDest,',', tempValSou,',', mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                        tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                        finalList.append(tempList)
    
    for number in range(0,10):
        if source_gate[flights] == 'HOU1' and destination_gate[flights] == 'AUS1':
            first_flight= 360
            departure_time= first_flight + count
            count=count + 150
            arrival_time= departure_time + flight_time['HOUAUS']
            tempValDest = destination_gate[flights][:3]
            tempValSou = source_gate[flights][:3]
            if departure_time >359 and arrival_time < 1321:
                print(tails[flights],',', tempValSou,',', tempValDest,',',mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                finalList.append(tempList)
                    
                if source_gate[flights] == 'HOU1' and destination_gate[flights] == 'AUS1':
                    departure_time= arrival_time + ground_time['AUS']
                    arrival_time = departure_time + flight_time['AUSDAL']
                    tempValDest = destination_gate[flights][:3]
                    tempValSou = source_gate[flights][:3]
                    if departure_time >359 and arrival_time < 1321:
                        print(tails[flights],',', tempValDest,',', tempValSou,',', mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                        tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                        finalList.append(tempList)
    
    for number in range(0,10):
        if source_gate[flights] == 'HOU2' and destination_gate[flights] == 'DAL1':
            first_flight= 360
            departure_time= first_flight + count
            count=count + 195
            arrival_time= departure_time + flight_time['HOUDAL']
            tempValDest = destination_gate[flights][:3]
            tempValSou = source_gate[flights][:3]
            if departure_time >359 and arrival_time < 1321:
                print(tails[flights],',', tempValSou,',', tempValDest,',',mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                finalList.append(tempList)
                    
                if source_gate[flights] == 'HOU2' and destination_gate[flights] == 'DAL1':
                    departure_time= arrival_time + ground_time['DAL']
                    arrival_time = departure_time + flight_time['DALHOU']
                    tempValDest = destination_gate[flights][:3]
                    tempValSou = source_gate[flights][:3]
                    if departure_time >359 and arrival_time < 1321:
                        print(tails[flights],',', tempValDest,',', tempValSou,',', mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                        tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                        finalList.append(tempList)
    
    for number in range(0,10):
        if source_gate[flights] == 'HOU3' and destination_gate[flights] == 'DAL2':
            first_flight= 360
            departure_time= first_flight + count
            count=count + 195
            arrival_time= departure_time + flight_time['HOUDAL']
            tempValDest = destination_gate[flights][:3]
            tempValSou = source_gate[flights][:3]
            if departure_time >359 and arrival_time < 1321:
                print(tails[flights],',', tempValSou,',', tempValDest,',',mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                finalList.append(tempList)
                
                if source_gate[flights] == 'HOU3' and destination_gate[flights] == 'DAL2':
                    departure_time= arrival_time + ground_time['DAL']
                    arrival_time = departure_time + flight_time['DALHOU']
                    tempValDest = destination_gate[flights][:3]
                    tempValSou = source_gate[flights][:3]
                    if departure_time >359 and arrival_time < 1321:
                        print(tails[flights],',', tempValDest,',', tempValSou,',', mins2militery(departure_time),',',mins2militery(arrival_time), sep="")
                        tempList = [ tails[flights], tempValSou, tempValDest, mins2militery(departure_time), mins2militery(arrival_time)]
                        finalList.append(tempList)
    
import csv
with open('flight_schedule.csv', 'wt') as fs:
    for s in finalList:
        print(','.join(s) , file=fs)
# Out:
# T1,AUS,HOU,0600,0645
# T1,HOU,AUS,0720,0805
# T1,AUS,HOU,0830,0915
# T1,HOU,AUS,0950,1035
# T1,AUS,HOU,1100,1145
# T1,HOU,AUS,1220,1305
# T1,AUS,HOU,1330,1415
# T1,HOU,AUS,1450,1535
# T1,AUS,HOU,1600,1645
# T1,HOU,AUS,1720,1805
# T1,AUS,HOU,1830,1915
# T1,HOU,AUS,1950,2035
# T1,AUS,HOU,2100,2145
# T2,DAL,HOU,0600,0705
# T2,HOU,DAL,0740,0845
# T2,DAL,HOU,0915,1020
# T2,HOU,DAL,1055,1200
# T2,DAL,HOU,1230,1335
# T2,HOU,DAL,1410,1515
# T2,DAL,HOU,1545,1650
# T2,HOU,DAL,1725,1830
# T2,DAL,HOU,1900,2005
# T2,HOU,DAL,2040,2145
# T3,DAL,HOU,0600,0705
# T3,HOU,DAL,0740,0845
# T3,DAL,HOU,0915,1020
# T3,HOU,DAL,1055,1200
# T3,DAL,HOU,1230,1335
# T3,HOU,DAL,1410,1515
# T3,DAL,HOU,1545,1650
# T3,HOU,DAL,1725,1830
# T3,DAL,HOU,1900,2005
# T3,HOU,DAL,2040,2145
# T4,HOU,AUS,0600,0645
# T4,AUS,HOU,0710,0800
# T4,HOU,AUS,0830,0915
# T4,AUS,HOU,0940,1030
# T4,HOU,AUS,1100,1145
# T4,AUS,HOU,1210,1300
# T4,HOU,AUS,1330,1415
# T4,AUS,HOU,1440,1530
# T4,HOU,AUS,1600,1645
# T4,AUS,HOU,1710,1800
# ...
